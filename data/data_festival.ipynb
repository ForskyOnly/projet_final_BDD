# %% [markdown]
# ### IMPORT DES BIBLIOTHÉQUES ET INITIALISATION DES OPTIONS

# %%
import pandas as pd
import requests
import os
from dotenv import load_dotenv
import json
import re
import time

# %%
pd.set_option('display.max_columns',None)

# %%
load_dotenv()
# Out:
# True

# %% [markdown]
# ### Réccupération des données de Festival de France avec l'API de DATA.GOUV

# %%
dataset_id = "festivals-global-festivals-_-pl"
api_key = os.getenv("API_KEY")  
url = f"https://data.culture.gouv.fr/api/v2/catalog/datasets/{dataset_id}/exports/json"

headers = {
    'X-API-KEY': api_key
}

response = requests.get(url, headers=headers)
print("Code d'état:", response.status_code)
print("Contenu de la réponse", response.text)

if response.status_code == 200:
    try:
        # Charger les données JSON depuis la réponse de l'API
        data = response.json()

        # Afficher les données JSON formatées
        print(json.dumps(data, indent=1))

        # Convertir les données en un DataFrame pandas
        df = pd.DataFrame(data)

        # Enregistrer le DataFrame au format CSV pour éviter les limitations de l'utilisation de l'api 
        csv_filename = 'festivals_data.csv'
        df.to_csv(csv_filename, index=False)
    except json.JSONDecodeError as e:
        print("Erreur de décodage JSON:", e)
else:
    print("Échec de la requête. Code d'état:", response.status_code)

# %% [markdown]
# ### EXPLORATION DU JEU DE DONNÉES

# %%
df = pd.read_csv("festivals_data.csv")

# %%
df.head(5)
# Out:
#                                  nom_du_festival envergure_territoriale  \
# 0                                         Gamerz         Départementale
# 1  Corsiclassic - festival de musique de chambre                    NaN
# 2                                Racines de ciel                    NaN
# 3                               Le grand bivouac         Intercommunale
# 4                                Festival Acthea                    NaN
#
#   region_principale_de_deroulement departement_principal_de_deroulement  \
# 0       Provence-Alpes-Côte d'Azur                     Bouches-du-Rhône
# 1                            Corse                         Corse-du-Sud
# 2                            Corse                         Corse-du-Sud
# 3             Auvergne-Rhône-Alpes                               Savoie
# 4                        Occitanie                                 Tarn
#
#   commune_principale_de_deroulement  \
# 0                   Aix-en-Provence
# 1                           Ajaccio
# 2                           Ajaccio
# 3                       Albertville
# 4                              Albi
#
#   code_postal_de_la_commune_principale_de_deroulement code_insee_commune  \
# 0                                              13090               13001
# 1                                              20000               2A004
# 2                                              20000               2A004
# 3                                              73200               73011
# 4                                              81000               81004
#
#   code_insee_epci_collage_en_valeur      libelle_epci_collage_en_valeur  \
# 0                         200054807  Métropole d'Aix-Marseille-Provence
# 1                         242010056                 CA du Pays Ajaccien
# 2                         242010056                 CA du Pays Ajaccien
# 3                         200068997                         CA Arlysère
# 4                         248100737             CA de l'Albigeois (C2A)
#
#   numero_de_voie type_de_voie_rue_avenue_boulevard_etc     nom_de_la_voie  \
# 0              1                                 Place  Victor schoelcher
# 1            NaN                                   Rue     Forcioli conti
# 2          50-52                                   Rue  Du cardinal Fesch
# 3         88 bis                                   Rue   de la République
# 4            NaN                                 Allée       Des Sciences
#
#                adresse_postale           complement_d_adresse_facultatif  \
# 0    1 Place Victor schoelcher                   Patio du bois de l'aune
# 1           Rue Forcioli conti                      Cathédrale d'Ajaccio
# 2  50-52 Rue Du cardinal Fesch                                       NaN
# 3  88 bis Rue de la République            Le Grand Bivouac d'Albertville
# 4           Allée Des Sciences  Ecoles Des Mines D'albi - Campus Jarlard
#
#                            site_internet_du_festival  \
# 0                    http://www.lab-gamerz.com/site/
# 1            helloasso.com/associations/corsiclassic
# 2     https://www.facebook.com/RacinesDeCielAjaccio/
# 3                    https://www.grandbivouac.com/fr
# 4  https://www.mines-albi.fr/acthea-17e-edition-d...
#
#                                       adresse_e_mail  \
# 0                             contact@lab-gamerz.com
# 1  Corsiclassic@gmail.com ou bartoli.jeanne@wanad...
# 2                              Viagrenelle@gmail.com
# 3                     communication@grandbivouac.org
# 4                                                NaN
#
#   decennie_de_creation_du_festival annee_de_creation_du_festival  \
# 0                   De 2000 à 2009                          2006
# 1                    2010 et après                          2016
# 2                   De 2000 à 2009                          2009
# 3                   De 2000 à 2009                          2002
# 4                              NaN                           NaN
#
#             discipline_dominante sous_categorie_spectacle_vivant  \
# 0  Arts visuels, arts numériques                             NaN
# 1                        Musique                             NaN
# 2             Livre, littérature                             NaN
# 3            Cinéma, audiovisuel                             NaN
# 4               Spectacle vivant                         Théâtre
#
#   sous_categorie_musique sous_categorie_musique_cnm  \
# 0                    NaN                        NaN
# 1      Musique classique                        NaN
# 2                    NaN                        NaN
# 3                    NaN                        NaN
# 4                    NaN                        NaN
#
#             sous_categorie_cinema_et_audiovisuel  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3  Films documentaires courts et moyens métrages
# 4                                            NaN
#
#   sous_categorie_arts_visuels_et_arts_numeriques  \
# 0                                Arts numériques
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#                  sous_categorie_livre_et_litterature  \
# 0                                                NaN
# 1                                                NaN
# 2  Fiction (roman, théâtre, etc.), Non-fiction (d...
# 3                                                NaN
# 4                                                NaN
#
#   periode_principale_de_deroulement_du_festival identifiant_agence_a  \
# 0      Après-saison (6 septembre - 31 décembre)                  NaN
# 1      Après-saison (6 septembre - 31 décembre)                  NaN
# 2          Avant-saison (1er janvier - 20 juin)                  NaN
# 3      Après-saison (6 septembre - 31 décembre)                  NaN
# 4          Avant-saison (1er janvier - 20 juin)                  NaN
#
#       identifiant                                  geocodage_xy  \
# 0   FEST_13001_49  {'lon': 5.39857444582, 'lat': 43.5360708378}
# 1   FEST_2A004_85  {'lon': 8.70132275974, 'lat': 41.9347926638}
# 2   FEST_2A004_96  {'lon': 8.70132275974, 'lat': 41.9347926638}
# 3  FEST_73011_104  {'lon': 6.40460338643, 'lat': 45.6683987277}
# 4  FEST_81004_113  {'lon': 2.14686328555, 'lat': 43.9258213622}
#
#    identifiant_cnm
# 0              NaN
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN

# %%
df.columns.tolist()
# Out:
# ['nom_du_festival',
#  'envergure_territoriale',
#  'region_principale_de_deroulement',
#  'departement_principal_de_deroulement',
#  'commune_principale_de_deroulement',
#  'code_postal_de_la_commune_principale_de_deroulement',
#  'code_insee_commune',
#  'code_insee_epci_collage_en_valeur',
#  'libelle_epci_collage_en_valeur',
#  'numero_de_voie',
#  'type_de_voie_rue_avenue_boulevard_etc',
#  'nom_de_la_voie',
#  'adresse_postale',
#  'complement_d_adresse_facultatif',
#  'site_internet_du_festival',
#  'adresse_e_mail',
#  'decennie_de_creation_du_festival',
#  'annee_de_creation_du_festival',
#  'discipline_dominante',
#  'sous_categorie_spectacle_vivant',
#  'sous_categorie_musique',
#  'sous_categorie_musique_cnm',
#  'sous_categorie_cinema_et_audiovisuel',
#  'sous_categorie_arts_visuels_et_arts_numeriques',
#  'sous_categorie_livre_et_litterature',
#  'periode_principale_de_deroulement_du_festival',
#  'identifiant_agence_a',
#  'identifiant',
#  'geocodage_xy',
#  'identifiant_cnm']

# %% [markdown]
# ### SUPPRESSION DES COLONNES INUTILES

# %%
df = df.drop([
 'envergure_territoriale',
 'code_insee_epci_collage_en_valeur',
 'libelle_epci_collage_en_valeur',
 'adresse_e_mail',
 'decennie_de_creation_du_festival',
 'identifiant_agence_a',
 'identifiant',
 'adresse_postale',
 'identifiant_cnm',], axis=1)

# %%
df.columns
# Out:
# Index(['nom_du_festival', 'region_principale_de_deroulement',
#        'departement_principal_de_deroulement',
#        'commune_principale_de_deroulement',
#        'code_postal_de_la_commune_principale_de_deroulement',
#        'code_insee_commune', 'numero_de_voie',
#        'type_de_voie_rue_avenue_boulevard_etc', 'nom_de_la_voie',
#        'complement_d_adresse_facultatif', 'site_internet_du_festival',
#        'annee_de_creation_du_festival', 'discipline_dominante',
#        'sous_categorie_spectacle_vivant', 'sous_categorie_musique',
#        'sous_categorie_musique_cnm', 'sous_categorie_cinema_et_audiovisuel',
#        'sous_categorie_arts_visuels_et_arts_numeriques',
#        'sous_categorie_livre_et_litterature',
#        'periode_principale_de_deroulement_du_festival', 'geocodage_xy'],
#       dtype='object')

# %% [markdown]
# ### CREATION D'UN NOUVEAU JEU DE DONNÉES

# %%
# Renommer certaines colonnes
df_renomme = df.rename(columns={
    'nom_du_festival': 'Nom_Festival',
    'region_principale_de_deroulement': 'Region',
    'departement_principal_de_deroulement': 'Departement',
    'commune_principale_de_deroulement': 'Commune',
    'code_insee_commune': 'Code_INSEE',
    'site_internet_du_festival': 'Site_Internet',
    'annee_de_creation_du_festival': 'Annee_Creation',
    'discipline_dominante': 'Discipline_Principale',
    'periode_principale_de_deroulement_du_festival': 'Periode',
    'geocodage_xy': 'Geocode'
})

# Convertir toutes les valeurs en chaînes de caractères avant de les combiner
colonnes_adresse = ['numero_de_voie', 'type_de_voie_rue_avenue_boulevard_etc', 
                    'nom_de_la_voie', 'code_postal_de_la_commune_principale_de_deroulement', 
                    'complement_d_adresse_facultatif']

df_renomme[colonnes_adresse] = df_renomme[colonnes_adresse].fillna('').astype(str)

# Créer la colonne 'Adresse_Postale'
df_renomme['Adresse_Postale'] = df_renomme[colonnes_adresse].agg(' '.join, axis=1)

# Regrouper les sous-catégories en une seule colonne 'Sous_Categorie'
colonnes_sous_categorie = ['sous_categorie_spectacle_vivant', 'sous_categorie_musique',
                           'sous_categorie_musique_cnm', 'sous_categorie_cinema_et_audiovisuel',
                           'sous_categorie_arts_visuels_et_arts_numeriques',
                           'sous_categorie_livre_et_litterature']

df_renomme[colonnes_sous_categorie] = df_renomme[colonnes_sous_categorie].fillna('').astype(str)

df_renomme['Sous_Categorie'] = df_renomme[colonnes_sous_categorie].agg(' '.join, axis=1)

# Sélectionner uniquement les colonnes nécessaires pour le nouveau DataFrame
colonnes_selectionnees = [
    'Nom_Festival', 'Region', 'Departement', 'Commune', 'Adresse_Postale', 
    'Code_INSEE', 'Site_Internet', 'Annee_Creation', 
    'Discipline_Principale', 'Sous_Categorie', 'Periode', 'Geocode'
]


df_festival = df_renomme[colonnes_selectionnees]

# %% [markdown]
# ### TRAITEMENT DES COLONNES

# %% [markdown]
# **Colonnes GeoCode**

# %%
# Création de colonne longitude et latitude et suppressopn de la colonne Geocode
df_festival['Geocode'] = df_festival['Geocode'].str.replace("'", "\"")

geocode_str = df_festival['Geocode'][0]
geocode_dict = json.loads(geocode_str)

df_festival['Geocode'] = df_festival['Geocode'].apply(lambda x: json.loads(x) if pd.notnull(x) else None)

df_festival['longitude'] = df_festival['Geocode'].apply(lambda x: x['lon'] if x is not None else None)
df_festival['latitude'] = df_festival['Geocode'].apply(lambda x: x['lat'] if x is not None else None)

df_festival.drop('Geocode', axis=1, inplace=True)

# %%
df_festival.tail(5)
# Out:
#                         Nom_Festival                      Region  \
# 7277                    Vitrollywood  Provence-Alpes-Côte d'Azur
# 7278                Entente Nocturne               Île-de-France
# 7279  Festival des cultures du monde        Auvergne-Rhône-Alpes
# 7280                     Buisso'Nied                   Grand Est
# 7281         Festival le Mois Kreyol                  Guadeloupe
#
#            Departement                Commune             Adresse_Postale  \
# 7277  Bouches-Du-Rhône              Vitrolles                      13127
# 7278      Val-de-Marne        Vitry-sur-Seine                      94400
# 7279             Isère                 Voiron  45 Avenue de Paviot 38500
# 7280           Moselle  Volmerange-lès-Boulay                      57320
# 7281        Guadeloupe                    NaN
#
#      Code_INSEE                                      Site_Internet  \
# 7277      13117                       facebook.com/vatoslocosvideo
# 7278      94081      http://lekilowatt.fr/agenda/entente-nocturne/
# 7279      38563  https://www.salmorencvoironculturesdumonde.com...
# 7280      57730  https://www.facebook.com/profile.php?id=100027...
# 7281        NaN                           https://lemoiskreyol.fr/
#
#            Annee_Creation Discipline_Principale           Sous_Catégorie  \
# 7277                  NaN   Cinéma, audiovisuel
# 7278  2018-01-01 00:00:00               Musique   Musiques actuelles
# 7279                 1983      Spectacle vivant               Danse
# 7280                 1994      Spectacle vivant               Conte
# 7281                 2017    Pluridisciplinaire
#
#                                        Periode  longitude   latitude
# 7277            Saison (21 juin - 5 septembre)   5.263578  43.449783
# 7278  Après-saison (6 septembre - 31 décembre)   2.394127  48.788283
# 7279            Saison (21 juin - 5 septembre)   5.582403  45.379172
# 7280  Après-saison (6 septembre - 31 décembre)   6.449554  49.170169
# 7281    Période variable selon les territoires        NaN        NaN

# %% [markdown]
# **Colonne Anne_Creation**

# %%
# nettoyer la date en gardant les 4 premiers caractères si la date est au format "AAAA-MM-JJ HH:MM:SS"

def clean_year(date_str):
    if isinstance(date_str, str):  
        if re.match(r"\d{4}-\d{2}-\d{2} \d{2}:\d{2}:\d{2}", date_str):
            return date_str[:4]  # Garder uniquement l'année
        elif re.match(r"\d{4}", date_str):
            return date_str
    return date_str 

# Uniformisation de la colonne Annee_Creation en  appliquant la fonction uniquement aux valeurs au format "YYYY-MM-DD HH:MM:SS"
df_festival['Annee_Creation'] = df_festival['Annee_Creation'].apply(clean_year)

# %%
df_festival['Annee_Creation'].unique()

# %%
# Suppression de toutes les caractéres non numérique de la colonne Anne_Creation 
def supprimer_non_numerique(year_str):
    if isinstance(year_str, str):
        return re.sub(r'\D', '', year_str)
    return None

df_festival['Annee_Creation'] = df_festival['Annee_Creation'].apply(supprimer_non_numerique)

# %%
df_festival['Annee_Creation'].unique()

# %%
# Remplacer "31564" par None  
df_festival['Annee_Creation'] = df_festival['Annee_Creation'].replace('31564', None)

def nettoyage_annee(year_str):
    if isinstance(year_str, str):
        # Pour les lignes avec plus de 4 caractères, garder uniquement les 4 premiers caractères
        if len(year_str) > 4:
            return year_str[:4]
        # Pour les lignes avec 2 caractères, les remplacer par "2024 - XX"
        elif len(year_str) == 2:
            return f"2024 - {year_str}"
        else:
            return year_str
    return year_str

df_festival['Annee_Creation'] = df_festival['Annee_Creation'].apply(nettoyage_annee)

# %%
def get_real_year(year_str):
    if isinstance(year_str, str):
        # Vérifier si la chaîne commence par "2024 - "
        if year_str.startswith("2024 - "):
            try:
                # Extraire XX de la chaîne
                xx = int(year_str.split("2024 - ")[1])
                # Calculer l'année réelle
                real_year = 2024 - xx
                return str(real_year)
            except ValueError:
                return year_str  # En cas d'erreur, retourner la chaîne d'origine
    return year_str

# Appliquer la fonction pour obtenir l'année réelle à la colonne 'Annee_Creation' de df_festival
df_festival['Annee_Creation'] = df_festival['Annee_Creation'].apply(get_real_year)

# %%
df_festival['Annee_Creation'].unique()
# Out:
# array(['2006', '2016', '2009', '2002', None, '2014', '1983', '1998',
#        '1996', '1980', '2004', '1997', '2015', '2000', '1999', '2010',
#        '1985', '2005', '2001', '1986', '1982', '1948', '2011', '1992',
#        '1989', '2019', '2018', '2003', '2007', '1993', '2017', '2012',
#        '2013', '1979', '1971', '1988', '2021', '1978', '1990', '1995',
#        '2008', '2020', '1946', '1966', '1987', '1984', '1972', '1991',
#        '1950', '1994', '1974', '1981', '1970', '1976', '1977', '1962',
#        '2022', '1973', '1968', '1969', '1967', '620', '1934', '9', '1920',
#        '1958', '1930', '1964', '8', '1905', '5', '1975', '1952', '1961',
#        '1923', '1604', '1956', '1874', '3', '1221', '1965', '1957',
#        '1954', '1947', '1960', '1944', '1951', '1949', '1935', '1959',
#        '520', '1869'], dtype=object)

# %%
def update_years(year_str):
    if isinstance(year_str, str):
        if len(year_str) == 1 or len(year_str) == 3:
            try:
                # Obtenir le premier caractère de la chaîne
                first_char = int(year_str[0])
                # Calculer l'année réelle
                real_year = 2024 - first_char
                return f"2024 - {real_year}"
            except ValueError:
                return year_str  # En cas d'erreur, retourner la chaîne d'origine
    return year_str

# mettre à jour les années à la colonne 'Annee_Creation' de df_festival
df_festival['Annee_Creation'] = df_festival['Annee_Creation'].apply(update_years)

# %%
df_festival['Annee_Creation'] = df_festival['Annee_Creation'].str.replace('2024 - ', '')

# %%
df_festival['Annee_Creation'].unique()

# %%
df_festival['Annee_Creation'] = df_festival['Annee_Creation'].replace(['1221', '1604'], None) ## a suppriemr

# %% [markdown]
# **Colonne Sous-Categorie**

# %%
# df_festival["Sous_Categorie"].unique().tolist()

# %%
def clean_sous_categorie(value):
    # Supprimer les numéros suivis d'un tiret et d'un espace
    value = re.sub(r'\d+\s*-\s*', '', value)
    # Supprimer les espaces au début et à la fin
    value = value.strip()
    # Remplacer les valeurs vides par 'Inconnu' 
    if not value:
        return 'Inconnu'
    return value


df_festival['Sous_Categorie'] = df_festival['Sous_Categorie'].apply(clean_sous_categorie)
# Out:
# /tmp/ipykernel_9173/2264096737.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_festival['Sous_Catégorie'] = df_festival['Sous_Catégorie'].apply(clean_sous_categorie)

# %%
# df_festival['Sous_Categorie'].unique().tolist()

# %% [markdown]
# **Colonne Period**
#  - Creation d'une nouvelle colonne 'Categorie_Periode'

# %%
def categoriser_periode(periode):
    if pd.isna(periode):
        return "Inconnu"
    periode = periode.lower()
    if 'avant-saison' in periode:
        return 'Avant-saison'
    elif 'après-saison' in periode:
        return 'Après-saison'
    elif 'saison' in periode:
        return 'Saison'
    elif any(mois in periode for mois in ['janvier', 'février', 'mars', 'avril', 'mai', 'juin', 'juillet', 'août', 'septembre', 'octobre', 'novembre', 'décembre']):
        return 'Mois spécifique'
    else:
        return 'Variable'

df_festival['Categorie_Periode'] = df_festival['Periode'].apply(categoriser_periode)
# Out:
# /tmp/ipykernel_9173/1557041798.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_festival['Categorie_Periode'] = df_festival['Periode'].apply(categoriser_periode)

# %% [markdown]
# **ADRESSE**

# %%
def get_address_from_coordinates(lat, lon):
    try:
        url = f"https://nominatim.openstreetmap.org/reverse?lat={lat}&lon={lon}&format=json"

        time.sleep(1)

        response = requests.get(url)

        # Vérifiez si la requête a réussi
        if response.status_code == 200:
            json_data = response.json()

            # Extraire l'adresse de la réponse JSON
            if "address" in json_data:
                address = json_data["address"]

                # Construire l'adresse complète depuis les donénes de l'api
                full_address = ", ".join(filter(None, [
                    address.get("road", ""),
                    address.get("quarter", ""),
                    address.get("city", ""),
                    address.get("municipality", ""),
                    address.get("county", ""),
                    address.get("state", ""),
                    address.get("region", ""),
                    address.get("postcode", "")
                ]))

                return full_address
    except Exception as e:
        print(f"Error getting address: {e}")
    return ""

df_festival['Adresse_Complete'] = df_festival.apply(lambda row: get_address_from_coordinates(row['latitude'], row['longitude']) if not pd.isna(row['latitude']) and not pd.isna(row['longitude']) else "", axis=1)
# Out:
# Error getting address: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=48.9719332783&lon=2.83158634864&format=json (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f8a5efb7b20>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
# /tmp/ipykernel_9173/151420464.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_festival['Adresse_Complete'] = df_festival.apply(lambda row: get_address_from_coordinates(row['latitude'], row['longitude']) if not pd.isna(row['latitude']) and not pd.isna(row['longitude']) else "", axis=1)

# %%
df_festival.rename(columns={'Adresse_Complete': 'Adresse_Postale'}, inplace=True)

# %%
df_festival.to_csv('Clean_Fest.csv')

# %%
import pandas as pd 
df = pd.read_csv('Clean_fest.csv')

# %%
df
# Out:
#                                        Nom_Festival  \
# 0                                            Gamerz
# 1     Corsiclassic - festival de musique de chambre
# 2                                   Racines de ciel
# 3                                  Le grand bivouac
# 4                                   Festival Acthea
# ...                                             ...
# 7277                                   Vitrollywood
# 7278                               Entente Nocturne
# 7279                 Festival des cultures du monde
# 7280                                    Buisso'Nied
# 7281                        Festival le Mois Kreyol
#
#                           Region       Departement                Commune  \
# 0     Provence-Alpes-Côte d'Azur  Bouches-du-Rhône        Aix-en-Provence
# 1                          Corse      Corse-du-Sud                Ajaccio
# 2                          Corse      Corse-du-Sud                Ajaccio
# 3           Auvergne-Rhône-Alpes            Savoie            Albertville
# 4                      Occitanie              Tarn                   Albi
# ...                          ...               ...                    ...
# 7277  Provence-Alpes-Côte d'Azur  Bouches-Du-Rhône              Vitrolles
# 7278               Île-de-France      Val-de-Marne        Vitry-sur-Seine
# 7279        Auvergne-Rhône-Alpes             Isère                 Voiron
# 7280                   Grand Est           Moselle  Volmerange-lès-Boulay
# 7281                  Guadeloupe        Guadeloupe                    NaN
#
#      Code_INSEE                                      Site_Internet  \
# 0         13001                    http://www.lab-gamerz.com/site/
# 1         2A004            helloasso.com/associations/corsiclassic
# 2         2A004     https://www.facebook.com/RacinesDeCielAjaccio/
# 3         73011                    https://www.grandbivouac.com/fr
# 4         81004  https://www.mines-albi.fr/acthea-17e-edition-d...
# ...         ...                                                ...
# 7277      13117                       facebook.com/vatoslocosvideo
# 7278      94081      http://lekilowatt.fr/agenda/entente-nocturne/
# 7279      38563  https://www.salmorencvoironculturesdumonde.com...
# 7280      57730  https://www.facebook.com/profile.php?id=100027...
# 7281        NaN                           https://lemoiskreyol.fr/
#
#       Annee_Creation          Discipline_Principale  \
# 0             2006.0  Arts visuels, arts numériques
# 1             2016.0                        Musique
# 2             2009.0             Livre, littérature
# 3             2002.0            Cinéma, audiovisuel
# 4                NaN               Spectacle vivant
# ...              ...                            ...
# 7277             NaN            Cinéma, audiovisuel
# 7278          2018.0                        Musique
# 7279          1983.0               Spectacle vivant
# 7280          1994.0               Spectacle vivant
# 7281          2017.0             Pluridisciplinaire
#
#                                          Sous_Catégorie  \
# 0                                       Arts numériques
# 1                                     Musique classique
# 2     Fiction (roman, théâtre, etc.), Non-fiction (d...
# 3         Films documentaires courts et moyens métrages
# 4                                               Théâtre
# ...                                                 ...
# 7277                                            Inconnu
# 7278                                 Musiques actuelles
# 7279                                              Danse
# 7280                                              Conte
# 7281                                            Inconnu
#
#                                        Periode  longitude   latitude  \
# 0     Après-saison (6 septembre - 31 décembre)   5.398574  43.536071
# 1     Après-saison (6 septembre - 31 décembre)   8.701323  41.934793
# 2         Avant-saison (1er janvier - 20 juin)   8.701323  41.934793
# 3     Après-saison (6 septembre - 31 décembre)   6.404603  45.668399
# 4         Avant-saison (1er janvier - 20 juin)   2.146863  43.925821
# ...                                        ...        ...        ...
# 7277            Saison (21 juin - 5 septembre)   5.263578  43.449783
# 7278  Après-saison (6 septembre - 31 décembre)   2.394127  48.788283
# 7279            Saison (21 juin - 5 septembre)   5.582403  45.379172
# 7280  Après-saison (6 septembre - 31 décembre)   6.449554  49.170169
# 7281    Période variable selon les territoires        NaN        NaN
#
#      Categorie_Periode                                    Adresse_Postale
# 0         Après-saison  Route de Berre, Aix-en-Provence, Aix-en-Proven...
# 1         Après-saison  D 11A, Ajaccio, Ajaccio, Corse-du-Sud, Corse, ...
# 2         Avant-saison  D 11A, Ajaccio, Ajaccio, Corse-du-Sud, Corse, ...
# 3         Après-saison  Route de Tours, Albertville, Savoie, Auvergne-...
# 4         Avant-saison  Rue du Mail, Albi, Tarn, Occitanie, France mét...
# ...                ...                                                ...
# 7277            Saison  Chemin de Vitrolles au Griffon, Les Pignes, Is...
# 7278      Après-saison  Passage Irène et Frédéric Joliot-Curie, L'Haÿ-...
# 7279            Saison  D 1075, Grenoble, Isère, Auvergne-Rhône-Alpes,...
# 7280      Après-saison  Rue du Moulin, Forbach-Boulay-Moselle, Moselle...
# 7281          Variable                                                NaN
#
# [7282 rows x 14 columns]
